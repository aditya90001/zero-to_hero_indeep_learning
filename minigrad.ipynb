# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
  return 3*x**2-4*x+5

# %%
f(3)
# Out:
# 20

# %%
xs=np.arange(-5,5,0.25)
xs
# Out:
# array([-5.  , -4.75, -4.5 , -4.25, -4.  , -3.75, -3.5 , -3.25, -3.  ,
#        -2.75, -2.5 , -2.25, -2.  , -1.75, -1.5 , -1.25, -1.  , -0.75,
#        -0.5 , -0.25,  0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ,
#         1.75,  2.  ,  2.25,  2.5 ,  2.75,  3.  ,  3.25,  3.5 ,  3.75,
#         4.  ,  4.25,  4.5 ,  4.75])

# %%
y=f(xs)

# %%
plt.plot(xs,y)

# %%
h=0.00000001
x=3
a=(f(x+h)-f(x))/h
a
# Out:
# 14.00000009255109

# %% [markdown]
# ## this simply mean by adding a small number in x how much my fx cahnge

# %%
## more complex
a=2
b=-3
c=10
d=a*b+c
d
# Out:
# 4

# %%
##now if i want to find derivative of d wrt a

h=0.0001
d1=a*b+c
a+=h
d2=a*b+c
df=(d2-d1)/h
print("di",d1)
print("d2",d2)
print("df",df)
# Out:
# di 4
# d2 3.999699999999999
# df -3.000000000010772

# %% [markdown]
# ## if we doing same thing with b then

# %%
h=0.0001
d1=a*b+c
b+=h
d2=a*b+c
df=(d2-d1)/h
print("di",d1)
print("d2",d2)
print("df",df)
# Out:
# di 3.999699999999999
# d2 3.99990001
# df 2.0001000000124947

# %%
a=2
b=-3
c=10
d=a*b+c
d
# Out:
# 4

# %%
## same thing with c

h=0.0001

c+=h
d2=a*b+c
df=(d2-d)/h

# %%
print(d2,df)
# Out:
# 4.0001 0.9999999999976694

# %%
## graident accumulate ho raha hain aap dekh skte ho

# %%
class value :
  def __init__(self,data):
    self.data=data
  def __repr__(self):
    return f"value(data={self.data}"
  def __add__(self,others):
    return self.data+others.data

# %%
a=value(5)
b=value(7)
c=a+b
c
# Out:
# 12

# %%
type(a)
# Out:
# __main__.value

# %%
type(c)
# means we loose our value object why
# Out:
# int

# %% [markdown]
# ## Operator overloading must return the same class to preserve object behavior.

# %%
class value :
  def __init__(self,data,_children=(),):
    self.data=data
    self.prev=set(_children)
  def __repr__(self):
    return f"value(data={self.data}"
  def __add__(self,others):
    return value(self.data+others.data,)
   #we don t write our class name
  def __mul__(self,others):
    return value(self.data*others.data)

# %% [markdown]
# Isliye tumhe __main__.value dikhta hai — matlab result ek value object hai, sirf number nahi.

# %%
c=a+b

# %%
type(c)
# Out:
# int

# %%
f=a+b
f
# Out:
# 12

# %%
d=value(12)

# %%
f.__mul__(d)
# Out:
# NotImplemented

# %% [markdown]
# ## these both are same

# %%
class value :
  def __init__(self,data,_children=(),):
    self.data=data
    self._prev=set(_children)
  def __repr__(self):
    return f"value(data={self.data}"
  def __add__(self,others):
    return value(self.data+others.data,(self,others))
   #we don t write our class name
  def __mul__(self,others):
    return value(self.data*others.data),(self,others)

# %%
## so when we create a value like object this
a=value(3)## for this chidren was empty and prev was empty set
## but when we create a value through addition or multplication  we r
## going to feed the children in the value

# %%
s=value(2)
d=value(10)

# %%
s._prev
## iske koi children nahi hain to ye khali set de raha hain
# Out:
# set()

# %%
y=s+d

# %%
## now i want to see children of this
## now i also want to see operation that happen on it

# %%
y._prev
# Out:
# {value(data=10, value(data=2}

# %%
class value :
  def __init__(self,data,_children=(),_op=''):
    self.data=data
    self._prev=set(_children)
    self._op=_op
  def __repr__(self):
    return f"value(data={self.data}"
  def __add__(self,others):
    return value(self.data+others.data,(self,others),'+')
   #we don t write our class name
  def __mul__(self,others):
    return value(self.data*others.data,(self,others),'*')

# %%
## now i can see what operation operate on that using function
y._op
# Out:
# '+'

# %%
## i also add one abel in my this
class value :
  def __init__(self,data,_children=(),_op='',label=''):
    self.grad=0
    self.data=data
    self._prev=set(_children)
    self._op=_op
    self.label=label
  def __repr__(self):
    return f"value(data={self.data}"
  def __add__(self,others):
    return value(self.data+others.data,(self,others),'+')
   #we don t write our class name
  def __mul__(self,others):
    return value(self.data*others.data,(self,others),'*')

# %%
df=value(5,"df")
dfs=value(6,"dfs")

# %% [markdown]
# ## i try to make a class by name of myself and it simply doādd and multiply

# %%
class aditya:
  def __init__(self,data,_prev=(),op='',grad):
    self.grad=0
    self.data=data
    self._prev=set(_prev)
    self.op=op
  def __repr__(self):
    return f"aditya(data={self.data}"
  def __add__(self,others):
    return aditya(self.data+others.data,(self,others),'+')
  def __mul__(self,others):
    return aditya(self.data*others.data,(self,others),'*')

# %%
a=aditya(5)
a
# Out:
# aditya(data=5

# %%
b=aditya(10)
b
# Out:
# aditya(data=10

# %%
c=a+b
c
# Out:
# aditya(data=15

# %%
c._prev
# Out:
# {aditya(data=10, aditya(data=5}

# %%
c.op
# Out:
# '+'

# %%
h=0.001
a = value(2.0, label='a')
b = value(-3.0, label='b')
c = value(10.0, label='c')
e = a*b; e.label = 'e'
d = e + c; d.label = 'd'
f = value(-2.0, label='f')
L = d * f; L.label = 'L'
L1=L.data

# %%
a = value(2.0, label='a')
b = value(-3.0, label='b')
c = value(10.0, label='c')
e = a*b; e.label = 'e'
d = e + c; d.label = 'd'
f = value(-2.0, label='f')
L = d * f; L.label = 'L'
L2=L.data

# %%
(L2-L1)/h ## derivative of l with f
# Out:
# 3.9999999999995595

# %% [markdown]
# ## so derivative of a number wrt to itself is always 1

# %%
from graphviz import Digraph

def trace(root):
  # builds a set of all nodes and edges in a graph
  nodes, edges = set(), set()
  def build(v):
    if v not in nodes:
      nodes.add(v)
      for child in v._prev:
        edges.add((child, v))
        build(child)
  build(root)
  return nodes, edges

def draw_dot(root):
  dot = Digraph(format='svg', graph_attr={'rankdir': 'LR'}) # LR = left to right

  nodes, edges = trace(root)
  for n in nodes:
    uid = str(id(n))
    # for any value in the graph, create a rectangular ('record') node for it
    dot.node(name = uid, label = "{ %s | data %.4f | grad %.4f }" % (n.label, n.data, n.grad), shape='record')
    if n._op:
      # if this value is a result of some operation, create an op node for it
      dot.node(name = uid + n._op, label = n._op)
      # and connect this node to it
      dot.edge(uid + n._op, uid)

  for n1, n2 in edges:
    # connect n1 to the op node of n2
    dot.edge(str(id(n1)), str(id(n2)) + n2._op)

  return dot

# %%
draw_dot(L)

# %%
# Out:
# '+'

# %%
## now lets focus on the derivative of d and f wrt x
dd/dc=e+c so it is equal to 1
dd/dc=((e+h)+c-(e+c))/h
dd/dc=h/h
=1

# %%
so now by symmetry
d=e+c
dd/de=1

# %%
L.grad=1
d.grad=-2
f.grad=4
c.grad=-2
e.grad=-2
a.grad=6
b.grad=-4

# %%
l=d*f
l
# Out:
# value(data=-8.0

# %%
h=0.001

# %%
##f(x+h)-f(x)/h## this is formula of derivative

# %%
l=d*f

# %%
##dl/dd=((d+h)*f-d*f)/h
#(d*f+h*f-d*f)/h
#(h*f)/h\
#=f

# %%
##now let,s find derivative of l wrt c
##l depend on d and d depend on c

# %%
##dl/dc=dl/dd*dd/dc

# %%
#-2*1=-2

# %%
## e=a*b
#dl/da=dl/de**de*da
#dl/da=-2*-3

# %%
## nowlets implment a back propogation using simple neural networks

# %%
x1=value(2,label='x1')
x2=value(0.0,label='x2')
## w1 and w2
w1=value(-3,label='w1')
w2=value(1,label='w2')
b=value(6.7,label='b')
x1w1=x1*w1;x1w1.label='x1*w1'
x2w2=x2*w2;x2w2.label='x2*w2'
x1w1x2w2=x1w1+x2w2;x1w1x2w2.label='x1*w1+x2*w2'
n=x1w1x2w2+b;n.label='n'
o=n.tanh()

# %%
## before apply activation function

# %%
draw_dot()

# %%
##after apply activation function
draw_dot(o)

# %%
## now we want to implmented tan h but tan h is hyberbloic function and we only define our add and mul in our class

# %%
class value :
  def __init__(self,data,_children=(),_op='',label=''):
    self.data=data
    self._prev=set(_children)
    self._op=_op
    self.label=label
    self.grad=0
  def __repr__(self):
    return f"value(data={self.data}"
  def __add__(self,others):
    return value(self.data+others.data,(self,others),'+')
  def __mul__(self,others):
    return value(self.data*others.data,(self,others),'*')
  def tanh(self):
    x=self.data
    t=(math.exp(2*x)-1)/(math.exp(2*x)+1)
    output=value(t,(self,),'tanh')
    return output

# %%
import math

# %%
## inc bias by
x1=value(2,label='x1')
x2=value(0.0,label='x2')
## w1 and w2
w1=value(-3,label='w1')
w2=value(1,label='w2')
b=value(6.8813735870195432,label='b')
x1w1=x1*w1;x1w1.label='x1*w1'
x2w2=x2*w2;x2w2.label='x2*w2'
x1w1x2w2=x1w1+x2w2;x1w1x2w2.label='x1*w1+x2*w2'
n=x1w1x2w2+b;n.label='n'
o=n.tanh();o.label='o'
draw_dot(o)

# %%
## it squeez value between -1 and 1
## lets start our backpropgation

# %%
o.grad=1

# %%
draw_dot(o)

# %%
## o=tanh(n) tanh ka drivative =1-tanh(n**2)

# %%
##do/dn=1-o**2

# %%
1-o.data**2
# Out:
# 0.4999999999999999

# %%
##do/dn=0.5
n.grad=0.5
x1w1x2w2.grad=0.5
b.grad=0.5

# %%
x1=value(2,label='x1')
x2=value(0.0,label='x2')
## w1 and w2
w1=value(-3,label='w1')
w2=value(1,label='w2')
b=value(6.8813735870195432,label='b')
x1w1=x1*w1;x1w1.label='x1*w1'
x2w2=x2*w2;x2w2.label='x2*w2'
x1w1x2w2=x1w1+x2w2;x1w1x2w2.label='x1*w1+x2*w2'
n=x1w1x2w2+b;n.label='n'
o=n.tanh();o.label='o'
